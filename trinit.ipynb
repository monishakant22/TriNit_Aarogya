# %% [markdown]
# <a href="https://colab.research.google.com/github/monishakant22/TriNit_Aarogya/blob/main/trinit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import os
import numpy as np
from PIL import Image
# import keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization
# !nvidia-smi
# Out:
# Sat Jan 29 20:53:30 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    27W /  70W |    270MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !unzip "/content/drive/MyDrive/COVID-19_Radiography_Dataset.zip" -d "/content"
# Out:
# Archive:  /content/drive/MyDrive/COVID-19_Radiography_Dataset.zip
# replace /content/COVID-19_Radiography_Dataset/Viral Pneumonia-1020.png? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import pandas as pd    
train = pd.read_csv("/content/file1.csv")
train["disease"]=train["disease"].apply(str)
print(train.shape)
# test = pd.read_csv(path_to_test_csv_file)
train_folder = "/content/COVID-19_Radiography_Dataset"
# test_folder = path_to_test_folder
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define your data generator
train_gen = ImageDataGenerator(rescale=1./255, validation_split=0.1)
# test_gen = ImageDataGenerator(rescale = 1.255)
train_data = train_gen.flow_from_dataframe(dataframe = train, 
directory = train_folder, x_col = "file_name", 
y_col = "disease", seed = 42,
batch_size = 64, shuffle = True, target_size = (299, 299),
class_mode="categorical")

# test_data = test_gen.flow_from_dataframe(dataframe = test, 
# directory = test_folder, x_col = name of your column with image, 
# y_col = None,
# batch_size = size of your batch, shuffle = False, 
# class_mode=None,target_size = (height of image, width of image))
# Out:
# (21165, 2)
# Found 21165 validated image filenames belonging to 4 classes.

# %%
dropout_perc=0.3
model = Sequential()
# train_data.batch_size, 
#################################################################
model.add(Conv2D(64, (3, 3), activation='relu',
          kernel_initializer='he_uniform', input_shape=(299, 299,3), padding="same"))
# model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(dropout_perc))
#################################################################
model.add(Conv2D(64, (3, 3),
          activation='relu', kernel_initializer='he_uniform', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(dropout_perc))
#################################################################
model.add(Conv2D(64, (3, 3),
          activation='relu', kernel_initializer='he_uniform', padding="same"))
# model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(dropout_perc))
#################################################################
model.add(Conv2D(64, (3, 3),
          activation='relu', kernel_initializer='he_uniform', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(dropout_perc))
#################################################################
model.add(Conv2D(64, (3, 3),
          activation='relu', kernel_initializer='he_uniform', padding="same"))
# model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(dropout_perc))
#################################################################
model.add(Conv2D(64, (3, 3),
          activation='relu', kernel_initializer='he_uniform', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(dropout_perc))
#################################################################
model.add(Conv2D(64, (3, 3),
          activation='relu', kernel_initializer='he_uniform', padding="same"))
# model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(dropout_perc))
#################################################################
model.add(Conv2D(64, (3, 3),
          activation='relu', kernel_initializer='he_uniform', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(dropout_perc))
#################################################################
model.add(Conv2D(64, (3, 3),
          activation='relu', kernel_initializer='he_uniform', padding="same"))
# model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(dropout_perc))
#################################################################
model.add(Conv2D(64, (3, 3),
          activation='relu', kernel_initializer='he_uniform', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(dropout_perc))
#################################################################
model.add(Conv2D(64, (3, 3),
          activation='relu', kernel_initializer='he_uniform', padding="same"))
# model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(dropout_perc))
#################################################################
model.add(Conv2D(64, (3, 3),
          activation='relu', kernel_initializer='he_uniform', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(dropout_perc))
#################################################################
model.add(Conv2D(64, (3, 3),
          activation='relu', kernel_initializer='he_uniform', padding="same"))
# model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(dropout_perc))
#################################################################
model.add(Conv2D(64, (3, 3),
          activation='relu', kernel_initializer='he_uniform', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(dropout_perc))
#################################################################
model.add(Conv2D(64, (3, 3),
          activation='relu', kernel_initializer='he_uniform', padding="same"))
# model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(dropout_perc))




model.add(Flatten())
model.add(Dense(256, activation='relu', kernel_initializer='he_uniform'))
# model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
# model.add(Dense(512, activation='relu', kernel_initializer='he_uniform'))

model.add(Dense(4, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=tf.optimizers.Adam(learning_rate=0.01),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_15 (Conv2D)          (None, 299, 299, 64)      1792
#
#  batch_normalization_14 (Bat  (None, 299, 299, 64)     256
#  chNormalization)
#
#  dropout_14 (Dropout)        (None, 299, 299, 64)      0
#
#  conv2d_16 (Conv2D)          (None, 299, 299, 64)      36928
#
#  max_pooling2d_7 (MaxPooling  (None, 149, 149, 64)     0
#  2D)
#
#  batch_normalization_15 (Bat  (None, 149, 149, 64)     256
#  chNormalization)
#
#  dropout_15 (Dropout)        (None, 149, 149, 64)      0
#
#  conv2d_17 (Conv2D)          (None, 149, 149, 64)      36928
#
#  batch_normalization_16 (Bat  (None, 149, 149, 64)     256
#  chNormalization)
#
#  dropout_16 (Dropout)        (None, 149, 149, 64)      0
#
#  conv2d_18 (Conv2D)          (None, 149, 149, 64)      36928
#
#  max_pooling2d_8 (MaxPooling  (None, 74, 74, 64)       0
#  2D)
#
# ...

# %%
STEP_SIZE_TRAIN=int(train.shape[0]/train_data.batch_size)

model.fit_generator(generator=train_data,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    epochs=30)
model.save("/content/cxr.h5")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/30
# 330/330 [==============================] - 324s 943ms/step - loss: 0.8500 - accuracy: 0.6766
# Epoch 2/30
# 330/330 [==============================] - 308s 932ms/step - loss: 0.6104 - accuracy: 0.7710
# Epoch 3/30
# 330/330 [==============================] - 311s 941ms/step - loss: 0.5335 - accuracy: 0.8020
# Epoch 4/30
# 330/330 [==============================] - 311s 943ms/step - loss: 0.4924 - accuracy: 0.8184
# Epoch 5/30
# 330/330 [==============================] - 311s 942ms/step - loss: 0.4740 - accuracy: 0.8248
# Epoch 6/30
# 330/330 [==============================] - 311s 943ms/step - loss: 0.4468 - accuracy: 0.8356
# Epoch 7/30
# 330/330 [==============================] - 311s 942ms/step - loss: 0.4309 - accuracy: 0.8415
# Epoch 8/30
# ...
